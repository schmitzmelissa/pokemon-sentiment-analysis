# %% [markdown]
# # Pokemon Sentiments
# A project to analyze the descriptions of Pokemon from PokemonDB.net.
#
# The webmaster has methods in place to prevent large-scale web scraping so I will be limiting my automated scripts to follow their rules.

# %%
from bs4 import BeautifulSoup
import requests
from requests import get
import pandas as pd
import numpy as np

# %% [markdown]
# ## Web Scraping
# The data we will be scraping includes:
# - National Pokemon ID#
# - Pokemon Name
# - Description Text
# - Generation of Description Text
#
# **Base URL:** http://pokemondb.net/pokedex/###
#
# where ### is the National Pokedex number (e.g., Bulbasaur is 001). There are a total of 893 Pokemon as of the introduction of the Galar region.
#
# The HTML we need is stored in the `<table class="vitals-table">`

# %%
url = "https://pokemondb.net/pokedex/001"
response = requests.get(url)
html = response.text

soup = BeautifulSoup(html, "html.parser")

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <title>
#    Bulbasaur Pokédex: stats, moves, evolution &amp; locations | Pokémon Database
#   </title>
#   <link href="https://fonts.gstatic.com" rel="preconnect"/>
#   <link href="https://img.pokemondb.net" rel="preconnect"/>
#   <link href="/static/css/pokemondb-e444f21899.css" rel="stylesheet"/>
#   <style>
#    .cell-barchart{width:100%;min-width:150px}.barchart-bar{height:.75rem;border-radius:4px;background-color:#a3a3a3;border:1px solid #737373;border-color:rgba(0,0,0,0.15)}.barchart-rank-1{background-color:#f34444}.barchart-rank-2{background-color:#ff7f0f}.barchart-rank-3{background-color:#ffdd57}.barchart-rank-4{background-color:#a0e515}.barchart-rank-5{background-color:#23cd5e}.barchart-rank-6{background-color:#00c2b8}.etymology>dd{margin-bottom:0}
# ...

# %%
id_numbers = []
names = []
desc_text = []
desc_generation = []

# %%
for container in desc_div:
    

desc_div = soup.find_all('td', class_ = 'cell-med-text')
print(desc_div)
# Out:
# [<td class="cell-med-text">A strange seed was planted on its back at birth. The plant sprouts and grows with this POKéMON.</td>, <td class="cell-med-text">It can go for days without eating a single morsel. In the bulb on its back, it stores energy.</td>, <td class="cell-med-text">The seed on its back is filled with nutrients. The seed grows steadily larger as its body grows.</td>, <td class="cell-med-text">It carries a seed on its back right from birth. As it grows older, the seed also grows larger.</td>, <td class="cell-med-text">While it is young, it uses the nutrients that are stored in the seeds on its back in order to grow.</td>, <td class="cell-med-text">BULBASAUR can be seen napping in bright sunlight. There is a seed on its back. By soaking up the sun’s rays, the seed grows progressively larger.</td>, <td class="cell-med-text">There is a plant seed on its back right from the day this POKéMON is born. The seed slowly grows larger.</td>, <td class="cell-med-text">A strange seed
# ...

# %%
desc = container.text
print(desc)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-df5ccac3e241> in <module>
# ----> 1 desc = container.text
#       2 print(desc)
#
# NameError: name 'container' is not defined
